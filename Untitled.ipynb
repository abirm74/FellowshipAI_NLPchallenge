# %%
# !pip install wordcloud
# !pip install spacy
# !pip install --upgrade spacy pydantic typing-extensions
# Out:
# Requirement already satisfied: wordcloud in d:\sw\conda\lib\site-packages (1.9.2)
# Requirement already satisfied: matplotlib in d:\sw\conda\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pillow in d:\sw\conda\lib\site-packages (from wordcloud) (9.5.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\abyrm\appdata\roaming\python\python39\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\sw\conda\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in d:\sw\conda\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\sw\conda\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in d:\sw\conda\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in d:\sw\conda\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\sw\conda\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: six>=1.5 in d:\sw\conda\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# Requirement already satisfied: spacy in d:\sw\conda\lib\site-packages (3.6.1)
# Requirement already satisfied: packaging>=20.0 in d:\sw\conda\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in d:\sw\conda\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\sw\conda\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\sw\conda\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\sw\conda\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\sw\conda\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\sw\conda\lib\site-packages (from spacy) (2.4.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\sw\conda\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: jinja2 in d:\sw\conda\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\sw\conda\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\sw\conda\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: setuptools in d:\sw\conda\lib\site-packages (from spacy) (63.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\sw\conda\lib\site-packages (from spacy) (2.0.9)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\abyrm\appdata\roaming\python\python39\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: pathy>=0.10.0 in d:\sw\conda\lib\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\sw\conda\lib\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\sw\conda\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in d:\sw\conda\lib\site-packages (from spacy) (8.1.12)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in d:\sw\conda\lib\site-packages (from spacy) (2.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\sw\conda\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\sw\conda\lib\site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: pydantic-core==2.6.3 in d:\sw\conda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.6.3)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\sw\conda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.5.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\sw\conda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\sw\conda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\sw\conda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\sw\conda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\sw\conda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\sw\conda\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\sw\conda\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.2)
# Requirement already satisfied: colorama in d:\sw\conda\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\sw\conda\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\sw\conda\lib\site-packages (from jinja2->spacy) (2.0.1)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# Requirement already satisfied: spacy in d:\sw\conda\lib\site-packages (3.6.1)
# Requirement already satisfied: pydantic in d:\sw\conda\lib\site-packages (2.3.0)
# Requirement already satisfied: typing-extensions in d:\sw\conda\lib\site-packages (4.7.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\sw\conda\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: jinja2 in d:\sw\conda\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\sw\conda\lib\site-packages (from spacy) (2.4.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\sw\conda\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\sw\conda\lib\site-packages (from spacy) (2.0.9)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\abyrm\appdata\roaming\python\python39\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\sw\conda\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\sw\conda\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: pathy>=0.10.0 in d:\sw\conda\lib\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\sw\conda\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in d:\sw\conda\lib\site-packages (from spacy) (8.1.12)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\sw\conda\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: packaging>=20.0 in d:\sw\conda\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: setuptools in d:\sw\conda\lib\site-packages (from spacy) (63.4.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\sw\conda\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\sw\conda\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in d:\sw\conda\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\sw\conda\lib\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\sw\conda\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\sw\conda\lib\site-packages (from pydantic) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in d:\sw\conda\lib\site-packages (from pydantic) (2.6.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\sw\conda\lib\site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in d:\sw\conda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\sw\conda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\sw\conda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in d:\sw\conda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\sw\conda\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\sw\conda\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.2)
# Requirement already satisfied: colorama in d:\sw\conda\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\sw\conda\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\sw\conda\lib\site-packages (from jinja2->spacy) (2.0.1)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in d:\sw\conda\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in d:\sw\conda\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: click in d:\sw\conda\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: tqdm in d:\sw\conda\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: joblib in d:\sw\conda\lib\site-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in d:\sw\conda\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: colorama in d:\sw\conda\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.0.0-py3-none-win_amd64.whl (99.7 MB)
#      ---------------------------------------- 99.7/99.7 MB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy in d:\sw\conda\lib\site-packages (from xgboost) (1.9.1)
# Requirement already satisfied: numpy in c:\users\abyrm\appdata\roaming\python\python39\site-packages (from xgboost) (1.24.3)
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.0
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\sw\conda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\sw\conda\lib\site-packages)

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\abyrm\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud,STOPWORDS
from nltk.tokenize import word_tokenize
from bs4 import BeautifulSoup
import spacy
import re,string,unicodedata
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.stem import LancasterStemmer,WordNetLemmatizer
from textblob import Word
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
import os
import warnings
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("IMDB Dataset.csv")

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %% [markdown]
# There are no missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
df['sentiment'].value_counts()
# Out:
# positive    25000
# negative    25000
# Name: sentiment, dtype: int64

# %%
# Check the distribution of sentiment labels
sentiment_counts = df['sentiment'].value_counts()
plt.bar(sentiment_counts.index, sentiment_counts.values)
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Distribution of Sentiment Labels')
plt.show()

# %% [markdown]
# The dataset is balanced

# %% [markdown]
# ## Data preprocessing

# %%
#Removing the html strips
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()
#Removing the square brackets
def remove_between_square_brackets(text):
    return re.sub('\[[^]]*\]', '', text)
#Removing the noisy text
def denoise_text(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    return text
#Apply function on review column
df['review']=df['review'].apply(denoise_text)
# Out:
# D:\sw\conda\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
#removing special characters
def remove_special_characters(text, remove_digits=True):
    pattern=r'[^a-zA-z0-9\s]'
    text=re.sub(pattern,'',text)
    return text
#Apply function on review column
df['review']=df['review'].apply(remove_special_characters)

# %%
#Stemming the text
def simple_stemmer(text):
    ps=nltk.porter.PorterStemmer()
    text= ' '.join([ps.stem(word) for word in text.split()])
    return text
#Apply function on review column
df['review']=df['review'].apply(simple_stemmer)

# %%
#Tokenization of text
tokenizer=ToktokTokenizer()
#Setting English stopwords
stopword_list=nltk.corpus.stopwords.words('english')

# %%
#set stopwords to english
stop=set(stopwords.words('english'))
print(stop)

#removing the stopwords
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text
#Apply function on review column
df['review']=df['review'].apply(remove_stopwords)
# Out:
# {'off', 'wasn', 'no', 'if', 'most', 'not', 'ours', "that'll", 'these', 'some', 'their', 've', "needn't", 'he', "wouldn't", 'you', 'so', 'yours', 'been', 'that', 'is', 'only', 'its', 'can', 're', 'while', "should've", 'should', 'each', 'i', 'my', 'now', "hasn't", 'for', "won't", 'such', 'shan', 'it', 'into', 'd', 'below', 'nor', "shouldn't", 'just', "couldn't", 'the', 'her', 'yourself', "shan't", 'couldn', 'how', 'same', 'having', 'few', 'as', 'herself', 'out', 'by', 's', 'with', 'will', 'itself', 'but', 'she', 'both', 'than', "wasn't", 'from', 'any', 'to', 'a', "mightn't", 'does', 'whom', 'didn', 'did', 'what', 'hers', 'through', 'then', "didn't", 'at', 'won', 'wouldn', 'between', "aren't", 'has', 'was', 'or', 'hasn', 't', 'll', "doesn't", 'theirs', 'himself', 'where', 'above', "you'll", 'needn', 'further', 'own', 'until', 'about', 'mustn', 'ain', 'had', "you've", "she's", 'were', 'ourselves', "you're", "hadn't", 'there', 'yourselves', 'being', 'under', 'be', 'shouldn', 'm', 'which', 'against', 'don', 'have', 'on', 'once', 'again', 'mightn', "weren't", 'myself', 'who', 'this', 'more', "you'd", 'me', 'doesn', 'are', 'because', 'ma', 'when', 'your', 'am', 'him', 'and', 'during', 'other', 'here', 'very', 'of', 'too', "mustn't", 'all', 'those', 'down', 'we', 'weren', 'his', 'they', 'in', 'do', 'doing', 'them', 'hadn', 'up', 'after', 'y', 'an', 'isn', "haven't", 'aren', 'our', 'haven', "isn't", 'why', "it's", 'before', 'o', 'over', "don't", 'themselves'}

# %% [markdown]
# Removing English Abreviations

# %%
def remove_abbriviations(text): 
    text = re.sub(r'won\'t', 'will not', text)  
    text = re.sub(r'can\'t', 'cannot', text)  
    text = re.sub(r'i\'m', 'i am', text)   
    text = re.sub(r'ain\'t', 'is not', text)  
    text = re.sub(r'(\w+)\'ll', '\g<1> will', text)  
    text = re.sub(r'(\w+)n\'t', '\g<1> not', text)  
    text = re.sub(r'(\w+)\'ve', '\g<1> have', text)  
    text = re.sub(r'(\w+)\'s', '\g<1> is', text)  
    text = re.sub(r'(\w+)\'re', '\g<1> are', text)  
    text = re.sub(r'(\w+)\'d', '\g<1> would', text)  
    text = re.sub(r'don\'t', 'do not', text)  
    text = re.sub(r'doesn\'t', 'does not', text)  
    text = re.sub(r'didn\'t', 'did not', text)  
    text = re.sub(r'haven\'t', 'have not', text)  
    text = re.sub(r'hasn\'t', 'has not', text)  
    text = re.sub(r'hadn\'t', 'had not', text)  
    text = re.sub(r'wouldn\'t', 'would not', text)  
    text = re.sub(r'shouldn\'t', 'should not', text)  
    text = re.sub(r'mustn\'t', 'must not', text)  
    text = re.sub(r'needn\'t', 'need not', text)  
    text = re.sub(r'it\'s', 'it is', text)  
    text = re.sub(r'they\'re', 'they are', text)  
    text = re.sub(r'we\'re', 'we are', text)  
    text = re.sub(r'you\'re', 'you are', text)  
    text = re.sub(r'he\'s', 'he is', text)  
    text = re.sub(r'she\'s', 'she is', text)  
    text = re.sub(r'we\'ll', 'we will', text)  
    text = re.sub(r'you\'ll', 'you will', text)  
    text = re.sub(r'they\'ll', 'they will', text)      
    return text 

df['review']=df['review'].apply(lambda z: remove_abbriviations(z))

# %% [markdown]
# ## EDA

# %%
words = []
for message in df['review']:
    words.extend([word for word in message.split() if word not in STOPWORDS])
        
wordcloud = WordCloud(width = 1000, height = 500).generate(" ".join(words))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
all_words=[]
for sentence in df['review']:
    all_words.extend(sentence.split())
nltk.FreqDist(all_words)
# Out:
# FreqDist({'thi': 145461, 'movi': 98936, 'wa': 95201, 'film': 92059, 'hi': 57279, 'one': 52649, 'like': 43820, 'ha': 33150, 'time': 29798, 'good': 28899, ...})

# %%
df['word_count'] = df['review'].apply(lambda x: len(str(x).split()) )  
df['character_count'] = df['review'].apply(lambda x: len(x))
df
# Out:
#                                                   review sentiment  \
# 0      one review ha mention watch 1 oz episod youll ...  positive
# 1      wonder littl product film techniqu veri unassu...  positive
# 2      thought thi wa wonder way spend time hot summe...  positive
# 3      basic famili littl boy jake think zombi hi clo...  negative
# 4      petter mattei love time money visual stun film...  positive
# ...                                                  ...       ...
# 49995  thought thi movi right good job wasnt creativ ...  positive
# 49996  bad plot bad dialogu bad act idiot direct anno...  negative
# 49997  cathol taught parochi elementari school nun ta...  negative
# 49998  im go disagre previou comment side maltin thi ...  negative
# 49999  one expect star trek movi high art fan expect ...  negative
#
#        word_count  character_count
# 0             175             1073
# 1              91              595
# 2              94              560
# 3              67              405
# 4             130              787
# ...           ...              ...
# 49995          93              536
# 49996          65              398
# 49997         124              772
# 49998         124              773
# 49999          75              410
#
# [50000 rows x 4 columns]

# %%
X=df['review']
y=df['sentiment']
# split into train and test sets To prevent data leakage 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Fit the encoder on the target labels (y_train) and transform them
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Now, y_train_encoded and y_test_encoded contain numerical labels (0 and 1)

# %% [markdown]
# ## TF-IDF Vectorizer

# %%
# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer(max_features=5000)  # You can adjust max_features as needed
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# Display the shapes of the resulting TF-IDF matrices and data splits
print('Training data shape (TF-IDF):', X_train_tfidf.shape, y_train.shape)
print('Testing data shape (TF-IDF):', X_test_tfidf.shape, y_test.shape)
# Out:
# Training data shape (TF-IDF): (33500, 5000) (33500,)
# Testing data shape (TF-IDF): (16500, 5000) (16500,)

# %%
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
#from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.svm import SVC

# Define the models and their names
models = [
    ("Logistic Regression", LogisticRegression(max_iter=1000)),
    ("XGBoost", XGBClassifier()),
    ("SVM" , SVC()),
    #("LGBM", LGBMClassifier())
]

# Create a DataFrame to store the results
results = pd.DataFrame(columns=["Model", "Accuracy", "Classification Report"])

# Iterate through the models
for name, model in models:
    # Create and train the model
    model.fit(X_train_tfidf, y_train_encoded)

    # Make predictions on the test set
    predictions = model.predict(X_test_tfidf)

    # Calculate accuracy
    accuracy = accuracy_score(y_test_encoded, predictions)

    # Generate the classification report
    report = classification_report(y_test_encoded, predictions, output_dict=True)

    # Append results to the DataFrame
    results = results.append({"Model": name, "Accuracy": accuracy, "Classification Report": report},
                             ignore_index=True)

# Print the results
print(results)
# Out:
# C:\Users\abyrm\AppData\Local\Temp\ipykernel_5508\2592891407.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": name, "Accuracy": accuracy, "Classification Report": report},
# C:\Users\abyrm\AppData\Local\Temp\ipykernel_5508\2592891407.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": name, "Accuracy": accuracy, "Classification Report": report},
